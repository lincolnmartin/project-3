# %%
import csv
import pandas as pd
import os

# %%
movies_path= os.path.join("data","ml-latest", "movies.csv")
movies_df= pd.read_csv(movies_path)
movies_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
links_path= os.path.join("data","ml-latest", "links.csv")
links_df= pd.read_csv(links_path)
links_df
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
merged_df= pd.merge(movies_df, links_df,how="outer", on="movieId" )
merged_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres   imdbId    tmdbId
# 0     Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1                      Adventure|Children|Fantasy   113497    8844.0
# 2                                  Comedy|Romance   113228   15602.0
# ...

# %%
ratings_path= os.path.join("data","ml-latest", "ratings.csv")
ratings_df= pd.read_csv(ratings_path)
ratings_df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
merged_df= pd.merge(merged_df, ratings_df,how="outer", on="movieId" )
merged_df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100849   193581  Black Butler: Book of the Atlantic (2017)
# 100850   193583               No Game No Life: Zero (2017)
# 100851   193585                               Flint (2017)
# 100852   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100853   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres   imdbId    tmdbId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# ...

# %%
genomescores_path= os.path.join("data","ml-latest", "genome-scores.csv")
scores_df= pd.read_csv(genomescores_path)
scores_df
# Out:
#          movieId  tagId  relevance
# 0              1      1    0.02900
# 1              1      2    0.02375
# 2              1      3    0.05425
# 3              1      4    0.06875
# 4              1      5    0.16000
# ...          ...    ...        ...
# 1048570     1024    659    0.01800
# 1048571     1024    660    0.09200
# 1048572     1024    661    0.03400
# 1048573     1024    662    0.03100
# 1048574     1024    663    0.05875
#
# [1048575 rows x 3 columns]

# %%
merged_df= pd.merge(merged_df, scores_df,how="outer", on="movieId" )
merged_df
# Out:
#           movieId             title  \
# 0               1  Toy Story (1995)
# 1               1  Toy Story (1995)
# 2               1  Toy Story (1995)
# 3               1  Toy Story (1995)
# 4               1  Toy Story (1995)
# ...           ...               ...
# 24984624     1002               NaN
# 24984625     1002               NaN
# 24984626     1002               NaN
# 24984627     1002               NaN
# 24984628     1002               NaN
#
#                                                genres    imdbId  tmdbId  \
# 0         Adventure|Animation|Children|Comedy|Fantasy  114709.0   862.0
# 1         Adventure|Animation|Children|Comedy|Fantasy  114709.0   862.0
# 2         Adventure|Animation|Children|Comedy|Fantasy  114709.0   862.0
# 3         Adventure|Animation|Children|Comedy|Fantasy  114709.0   862.0
# 4         Adventure|Animation|Children|Comedy|Fantasy  114709.0   862.0
# ...                                               ...       ...     ...
# ...

# %%
merged_df.to_csv('newcleandata.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:261, in CSVFormatter.save(self)
#     251 self.writer = csvlib.writer(
#     252     handles.handle,
#     253     lineterminator=self.lineterminator,
#    (...)
#     258     quotechar=self.quotechar,
#     259 )
# --> 261 self._save()
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:266, in CSVFormatter._save(self)
#     265     self._save_header()
# --> 266 self._save_body()
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:304, in CSVFormatter._save_body(self)
#     303     break
# --> 304 self._save_chunk(start_i, end_i)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:315, in CSVFormatter._save_chunk(self, start_i, end_i)
#     314 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# ...
